# %% [markdown]
# USC Children's Data Network
#
# __RECORD RECONCILIATION PROJECT__
#
# Date: 08 January 2020
#
# __Description__ : This module contains the functions neccessary to perform the masking procedures for the dashboard reports for each of the programs. Primary masking hides low counts in range (0,10] by chaning the cell value to _*1_. Secondary masking is performed for categories of the same group, or for each column, to prevent deduction of the primarily masked cell by arithmetics. In other words, if a cell in a related group is primarily masked, then the next lowest cell count in that group will be secondarily masked.
#
#         Example: A row of data has value [5,*1] for columns [Male, Female]. The value of -999 may be calculated by subtracting [5] from the row total. Secondary masking will transform this group to [*2,*1].
#
# __General Procedure__: The module accepts unmasked Excel report files, and split the report into separate dataframes for each geography level (e.g.: State Assembly, State Senate etc.) Note that the unmasked Excel files are already primarily masked, but with values of -999 instead of _*1_ . The function _createGroupdict_ generates a Python dictionary of related cell groups, depending on the program. This dictionary is used to performed horizontal masking, which iterates through each row, by each group to check whether secondary masking is needed. After the rows have been checked, each column is also tested by similar logic, as arithmetic deduction may be done vertically as well. Finally, the separate dataframes are re-joined together to match the original shape.
#
# __General Sequence__:
#
# *   Step 1. Run createGroupDict to create dictionary of horizontal groups _([Male,Female],[Asian, Black, White, Hispanic, Native  Am./other/missing])_.
# *  Step 2. Run batchMask, wich first calls splitReport to separete dataframes by geographical levels. Then calls horizontalMask and verticalMask sequentially on them for masking. Finally re-join them into a single dataframe again.
# *   Step 3. Export masked dataframe to new Excel file.

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### FUNCTION INVENTORY ###

# %%
def splitReport(df:pd.DataFrame, geo=["State Assembly Total","State Senate Total"
                                      ,"U.S. Congress Total"
                                     ,"County Total"]):
    '''
    Accept a DF that is the original Excel report,
    split into N sub-reports based on geographies as 
    lited by the geo parameter.
    :param df: Pandas Dataframe.
    :param geo: List of strings, names of each level of geography.
    :return split_dfs: List of split dataframes.
    '''
    #We can identify each section of the report here...
    indices = np.zeros(len(geo),dtype='int')
    split_dfs = []
    #Look up the index of the last row of each geography level, usually subtotal rows.
    for idx in range(len(geo)):
        print("GEOGRAPHY level:", geo[idx])
        indices[idx] = df.index[df.Number == geo[idx]].tolist()[0]
        if idx == 0:
            split_dfs.append(df.iloc[:indices[idx]+1])
        else:
            split_dfs.append(df.iloc[indices[idx-1]+1:indices[idx]+1])
    return split_dfs

# %%
def createGroupdict(prog):
    '''
    For each program, create a dictionary of groups of related variables. This is necesarry because there are slight 
    variations between programs.
    :param prog: A string. Name of program (ex: "WIC","CalFresh" etc...)
    :return group_dict: A Python dictionary of related groups of variables for each program.
    '''
    group_dict = dict()
    #Populate dictionary
    group_dict["race"] =  ['Asian_PI','Black', 'Hispanic', 'Native American/Other/Unknown',"White"]
    group_dict["prog"] = ['1 program', '2 programs', '3 programs','4 programs', '5+ programs']
    group_dict["agy"] = ['1 department', '2 departments','3 departments', '4 departments']
    #Variable fields...
    group_dict["age1"] = ['17 and Under', '18 and Over']
    group_dict["age2"] = ['18-64','65 and Over']
    group_dict["gender"] = ['Female','Male', 'Unknown/Other Gender']
    #Special modifications for each program 
    if prog.upper() == 'WIC': 
        group_dict["gender"] = ['Female','Male']
        group_dict["age1"]  = ['less than 19', '20 to 24', '25 to 29', '30 to 34','35 and over']
        group_dict["age2"]  = ['wic age 0','wic age 1','wic age 2','wic age 3','wic age 4','wic age 5 to 19',
                               'wic age 20 and Over']
    elif prog.upper() == "CWS_CMS" :
        group_dict["age1"] = ['age1 missing','17 and Under', '18 and Over']
        group_dict["age2"] = ['age2 missing', '18-64', '65 and Over']
        group_dict["fcage"] = ['fc age missing','age 0', '1 to 2', '3 to 5','6 to 10', '11 to 15', '16 to 17', '18 to 20']
    elif prog.upper() == "FC" :
        del group_dict['age2'] #no need to mask group with only 1 variable
        group_dict["fcage"] = ['age 0', '1 to 2', '3 to 5','6 to 10', '11 to 15', '16 to 17', '18 to 20']
    elif prog.upper() =='FPACT':
        group_dict["gender"] = ['Female','Male']
    elif prog.upper() =='MEDICAL':
        group_dict["gender"] = ['Female','Male']
    elif prog.upper() == "CALFRESH":
        group_dict["gender"] = ['Female','Male']
        group_dict["age1"]  = ['17 and Under','18 to 59', '60 and Over']
    elif prog.upper() in  ['IHSS','CALWORKS','DDS']: 
        group_dict["gender"] = ['Female','Male']
    

    return group_dict

# %%
def verticalMask(df, drop_cols = ['Program', 'Level', 'Number']):
    '''Asssuming the dataframe only contains 1 geography,
    iterrate through each column to perform vertical masking.
    :param df: Dataframe
    :param drop_cols: list of columns to NOT be masked/ignored (non-data columns)
    :return d: Dataframe, veritically masked
    '''
    d = df.copy()
    #Iteratate through every report column
    cols = list(set(d.columns.tolist()) - set(drop_cols))
    
    for c in cols:
        print("...Processing column",c)
        #Only mask if a single number in that column is -999
#         print(np.sum(d.loc[d[c] < 0, c]))
        if sum(d.loc[d[c] < 0, c]) == -999: 
#             print("Single -999 value found. Secondary masking done!")
            # Only mask 0 cell when no other non-zero cell present
            next_min_a = np.min(d.loc[d[c] >= 0 , c])
            next_min_b = np.min(d.loc[d[c] > 0 , c])
            #Only secondary mask 0 if it is the true next smallest. 
#             print("min_a",next_min_a,"min_b",next_min_b)
            next_min = max(next_min_a, next_min_b )
#             next_min_idx = np.where(d[c].values  ==next_min)[0][0] 
            col_values = d[c]
#             print("col_values",col_values)
            next_min_idx = col_values[col_values == next_min].index.tolist()[0]
            print("The next smallest value for column {} is at index {} of value {}".format(c,next_min_idx,next_min))
            #Secondary mask 
            d.loc[next_min_idx, c] = -100 #placeholder value
    return d

# %%
def secondMask(row):
    '''
    Helper function. Perform secondary masking for a single vector by checking if an element is 
    -999 (placeholder for original primary masking).
    :param row: a numpy vector
    :return row: secondarily masked row vector
    '''
    #If -999 exists, find the index of next smallest cell to mask
    if len(row[row ==  -999]) == 1:
#         print("Row before:\n", row)
        # Only mask 0 cell when no other non-zero cells present
        next_min_a = np.min(row[row >= 0])
        next_min_b = np.min(row[row > 0])
        next_min  = max(next_min_a, next_min_b) 
        next_min_idx = np.where(row==next_min)[0][0] #Remember the index of next-smallest cell
#         next_min_idx = row[row==next_min].index.tolist()[0]
        print("Next smallest at index {} of value {}".format(next_min_idx, next_min))
        #Change value of masked cell, temporarily to -100 (numeric values easier to keep track)
        row[next_min_idx] = -100
#         print("Row after:\n", row)
    return row

# %%
def horizontalMask(df, grp:dict):
    '''
    Leveraging the secondMask function, change the 
    group of related column names, then perform masking 
    within the parameters for each row in group. 
    :param df: Pandas dataframe
    :param grp: dictionary of group names, from createGroupdict.
    :return d: Dataframe, horizontally masked.
    '''
    d = df.copy()
    #Apply secondMask for each row
    for k,v in grp.items():
        print("Now looking at group,",k)
        d.loc[:,v] = d.loc[:,v].apply(secondMask, axis=1)
    return d

# %%
def batchMask(df, grp):
    '''
    Wrapper function. Performs both horizontal and vertical secondary masking for an entire dataframe 
    by calling previous helper functions.
    :param df: Dataframe, from original Excel file. 
    :param grp: dictionary, from createGroupDict
    :return final_df: Dataframe, masked and concatenated
    '''
    masked_df = splitReport(df)
    final_df = pd.DataFrame()
    #Perform masking for each split frame 
    for i in range(len(masked_df)):
#         print("-----------NOW LOOKING AT GEOGRAPHY-------", masked_df[i]["Level"])
        #Horizontal masking
        masked_df[i] = horizontalMask(masked_df[i], grp )
        #Vertical masking
        masked_df[i] = verticalMask(masked_df[i])   
        #Concatenate frames together
        final_df = pd.concat([final_df, masked_df[i]], ignore_index=True)
        
#     #Finally, change al -999 and -100 into *1 and *2, respectively;
    final_df = final_df.replace(-999,"*1")
    final_df = final_df.replace(-100,"*2")

#     if ! assert df.shape == final_df.shape: 
#         print("Final dataframe does NOT preserve original shape!!")
    final_df = final_df.reset_index(drop=True)
    return final_df

# %% [markdown]
# ## PRODUCTION TEST

# %% [markdown]
# ## MANUAL FOR EACH PROGRAM

# %%
prog = "FC"
year = '18'
d = pd.read_excel('Dashboard_'+ year+"//" + prog +"_Dashboard_" + year+ ".xlsx")
d.columns
# Out:
# Index(['fileyear', 'Program', 'Level', 'Number', 'Child Welfare', 'Medi-Cal',
#        'FPACT', 'CalFresh', 'CalWorks', 'IHSS', 'DDS', 'WIC',
#        'Native American/Other/Unknown', 'Black', 'White', 'Hispanic',
#        'Asian_PI', 'Female', 'Male', 'Unknown/Other Gender', '17 and Under',
#        '18 and Over', '18-64', 'age 0', '1 to 2', '3 to 5', '6 to 10',
#        '11 to 15', '16 to 17', '18 to 20', '1 program', '2 programs',
#        '3 programs', '4 programs', '5+ programs', '1 department',
#        '2 departments', '3 departments', '4 departments'],
#       dtype='object')

# %%
group_dict = createGroupdict(prog)

# %%
r = batchMask(d, group_dict)
# Out:
# GEOGRAPHY level: State Assembly Total
# GEOGRAPHY level: State Senate Total
# GEOGRAPHY level: U.S. Congress Total
# GEOGRAPHY level: County Total
# Now looking at group, race
# Next smallest at index 3 of value 25
# Next smallest at index 3 of value 17
# Next smallest at index 3 of value 16
# Next smallest at index 0 of value 20
# Next smallest at index 0 of value 69
# Next smallest at index 0 of value 43
# Next smallest at index 1 of value 23
# Next smallest at index 0 of value 37
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 23
# Next smallest at index 0 of value 32
# Next smallest at index 0 of value 24
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 24
# Next smallest at index 3 of value 24
# Next smallest at index 0 of value 11
# Next smallest at index 3 of value 13
# Next smallest at index 0 of value 30
# Next smallest at index 0 of value 29
# Next smallest at index 1 of value 11
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 36
# Next smallest at index 0 of value 19
# Next smallest at index 1 of value 21
# Next smallest at index 1 of value 57
# Next smallest at index 0 of value 17
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 38
# Next smallest at index 1 of value 12
# Next smallest at index 1 of value 45
# Next smallest at index 4 of value 45
# Next smallest at index 4 of value 53
# Next smallest at index 0 of value 18
# Next smallest at index 1 of value 24
# Next smallest at index 3 of value 12
# Next smallest at index 1 of value 26
# Next smallest at index 4 of value 51
# Next smallest at index 4 of value 30
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 11
# Next smallest at index 0 of value 25
# Next smallest at index 4 of value 57
# Next smallest at index 0 of value 24
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 11
# Next smallest at index 0 of value 15
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 100
# Next smallest at index 3 of value 30
# Next smallest at index 1 of value 11
# Next smallest at index 3 of value 22
# Next smallest at index 0 of value 12
# Next smallest at index 0 of value 11
# Next smallest at index 0 of value 17
# Now looking at group, prog
# Next smallest at index 4 of value 16
# Next smallest at index 4 of value 39
# Next smallest at index 4 of value 49
# Next smallest at index 4 of value 23
# Next smallest at index 4 of value 16
# Next smallest at index 4 of value 33
# Next smallest at index 4 of value 15
# Next smallest at index 4 of value 98
# Next smallest at index 4 of value 14
# Next smallest at index 4 of value 31
# Next smallest at index 4 of value 11
# Next smallest at index 4 of value 19
# Next smallest at index 4 of value 37
# Next smallest at index 4 of value 137
# Next smallest at index 4 of value 62
# Next smallest at index 4 of value 27
# Next smallest at index 4 of value 27
# Next smallest at index 4 of value 39
# Next smallest at index 4 of value 24
# Next smallest at index 4 of value 38
# Next smallest at index 4 of value 46
# Next smallest at index 4 of value 103
# Next smallest at index 4 of value 100
# Next smallest at index 4 of value 64
# Next smallest at index 4 of value 19
# Next smallest at index 4 of value 109
# Next smallest at index 4 of value 86
# Next smallest at index 4 of value 21
# Next smallest at index 4 of value 122
# Next smallest at index 4 of value 70
# Next smallest at index 4 of value 77
# Next smallest at index 4 of value 32
# Next smallest at index 4 of value 57
# Next smallest at index 4 of value 25
# Next smallest at index 4 of value 39
# Next smallest at index 4 of value 44
# Next smallest at index 4 of value 107
# Next smallest at index 4 of value 48
# Next smallest at index 4 of value 32
# Next smallest at index 4 of value 20
# Next smallest at index 4 of value 23
# Next smallest at index 4 of value 19
# Next smallest at index 4 of value 22
# Next smallest at index 4 of value 39
# Next smallest at index 4 of value 51
# Now looking at group, agy
# Next smallest at index 0 of value 19
# Next smallest at index 3 of value 14
# Next smallest at index 3 of value 22
# Next smallest at index 3 of value 35
# Next smallest at index 3 of value 16
# Next smallest at index 3 of value 20
# Next smallest at index 3 of value 58
# Next smallest at index 3 of value 22
# Next smallest at index 3 of value 14
# Next smallest at index 3 of value 19
# Next smallest at index 3 of value 99
# Next smallest at index 3 of value 39
# Next smallest at index 3 of value 26
# Next smallest at index 3 of value 41
# Next smallest at index 3 of value 36
# Next smallest at index 3 of value 23
# Next smallest at index 3 of value 45
# Next smallest at index 3 of value 48
# Next smallest at index 3 of value 95
# Next smallest at index 3 of value 105
# Next smallest at index 3 of value 57
# Next smallest at index 3 of value 22
# Next smallest at index 3 of value 113
# Next smallest at index 3 of value 70
# Next smallest at index 3 of value 16
# Next smallest at index 3 of value 49
# Next smallest at index 3 of value 77
# Next smallest at index 3 of value 87
# Next smallest at index 3 of value 33
# Next smallest at index 3 of value 55
# Next smallest at index 3 of value 31
# Next smallest at index 3 of value 31
# Next smallest at index 3 of value 18
# Next smallest at index 3 of value 122
# Next smallest at index 3 of value 41
# Next smallest at index 3 of value 30
# Next smallest at index 3 of value 28
# Next smallest at index 3 of value 19
# Next smallest at index 3 of value 18
# Next smallest at index 3 of value 31
# Next smallest at index 3 of value 44
# Now looking at group, age1
# Now looking at group, gender
# Next smallest at index 0 of value 1752
# Next smallest at index 0 of value 1752
# Next smallest at index 1 of value 410
# Next smallest at index 1 of value 163
# Next smallest at index 0 of value 250
# Next smallest at index 0 of value 31490
# Now looking at group, fcage
# Next smallest at index 1 of value 31
# Next smallest at index 5 of value 21
# Next smallest at index 5 of value 25
# ...Processing column Asian_PI
# ...Processing column 3 departments
# ...Processing column CalWorks
# The next smallest value for column CalWorks is at index 22 of value 12
# ...Processing column Hispanic
# ...Processing column Black
# ...Processing column 16 to 17
# ...Processing column 18 to 20
# ...Processing column 5+ programs
# ...Processing column 4 departments
# ...Processing column fileyear
# ...Processing column 18 and Over
# ...Processing column DDS
# ...Processing column 1 program
# ...Processing column 6 to 10
# ...Processing column 1 to 2
# ...Processing column IHSS
# ...Processing column Female
# ...Processing column 3 to 5
# ...Processing column 11 to 15
# ...Processing column 2 programs
# ...Processing column 18-64
# ...Processing column FPACT
# ...Processing column 3 programs
# ...Processing column 2 departments
# ...Processing column 4 programs
# The next smallest value for column 4 programs is at index 24 of value 15
# ...Processing column 17 and Under
# ...Processing column WIC
# ...Processing column Child Welfare
# ...Processing column 1 department
# ...Processing column Native American/Other/Unknown
# ...Processing column Unknown/Other Gender
# ...Processing column age 0
# ...Processing column Male
# ...Processing column White
# ...Processing column CalFresh
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 0 of value 42
# Next smallest at index 0 of value 61
# Next smallest at index 0 of value 57
# Next smallest at index 0 of value 29
# Next smallest at index 0 of value 28
# Next smallest at index 0 of value 46
# Next smallest at index 0 of value 30
# Next smallest at index 0 of value 17
# Next smallest at index 0 of value 47
# Next smallest at index 0 of value 65
# Next smallest at index 4 of value 87
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 11
# Next smallest at index 0 of value 53
# Next smallest at index 4 of value 86
# Next smallest at index 0 of value 27
# Next smallest at index 1 of value 106
# Next smallest at index 4 of value 158
# Next smallest at index 1 of value 36
# Next smallest at index 0 of value 15
# Next smallest at index 0 of value 27
# Next smallest at index 0 of value 21
# Now looking at group, prog
# Next smallest at index 4 of value 29
# Next smallest at index 4 of value 39
# Next smallest at index 0 of value 11
# Next smallest at index 4 of value 32
# Next smallest at index 4 of value 93
# Next smallest at index 4 of value 62
# Next smallest at index 4 of value 63
# Next smallest at index 4 of value 96
# Next smallest at index 4 of value 28
# Next smallest at index 4 of value 65
# Next smallest at index 4 of value 139
# Now looking at group, agy
# Next smallest at index 3 of value 14
# Next smallest at index 3 of value 25
# Next smallest at index 0 of value 11
# Next smallest at index 3 of value 22
# Next smallest at index 3 of value 80
# Next smallest at index 3 of value 64
# Next smallest at index 3 of value 76
# Next smallest at index 3 of value 44
# Next smallest at index 3 of value 23
# Next smallest at index 3 of value 56
# Next smallest at index 3 of value 96
# Now looking at group, age1
# Now looking at group, gender
# Next smallest at index 0 of value 1714
# Next smallest at index 0 of value 1714
# Next smallest at index 0 of value 790
# Next smallest at index 1 of value 863
# Next smallest at index 0 of value 720
# Next smallest at index 0 of value 31490
# Now looking at group, fcage
# ...Processing column Asian_PI
# ...Processing column 3 departments
# ...Processing column CalWorks
# ...Processing column Hispanic
# ...Processing column Black
# ...Processing column 16 to 17
# ...Processing column 18 to 20
# ...Processing column 5+ programs
# ...Processing column 4 departments
# ...Processing column fileyear
# ...Processing column 18 and Over
# ...Processing column DDS
# ...Processing column 1 program
# ...Processing column 6 to 10
# ...Processing column 1 to 2
# ...Processing column IHSS
# ...Processing column Female
# ...Processing column 3 to 5
# ...Processing column 11 to 15
# ...Processing column 2 programs
# ...Processing column 18-64
# ...Processing column FPACT
# ...Processing column 3 programs
# ...Processing column 2 departments
# ...Processing column 4 programs
# ...Processing column 17 and Under
# ...Processing column WIC
# ...Processing column Child Welfare
# ...Processing column 1 department
# ...Processing column Native American/Other/Unknown
# ...Processing column Unknown/Other Gender
# ...Processing column age 0
# ...Processing column Male
# ...Processing column White
# ...Processing column CalFresh
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 3 of value 22
# Next smallest at index 0 of value 48
# Next smallest at index 0 of value 41
# Next smallest at index 0 of value 23
# Next smallest at index 0 of value 38
# Next smallest at index 0 of value 29
# Next smallest at index 1 of value 32
# Next smallest at index 0 of value 16
# Next smallest at index 0 of value 51
# Next smallest at index 0 of value 31
# Next smallest at index 0 of value 33
# Next smallest at index 0 of value 16
# Next smallest at index 0 of value 29
# Next smallest at index 0 of value 11
# Next smallest at index 0 of value 37
# Next smallest at index 0 of value 49
# Next smallest at index 0 of value 14
# Next smallest at index 0 of value 74
# Next smallest at index 0 of value 44
# Next smallest at index 1 of value 74
# Next smallest at index 0 of value 40
# Next smallest at index 4 of value 54
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 59
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 43
# Next smallest at index 0 of value 114
# Next smallest at index 0 of value 11
# Next smallest at index 3 of value 35
# Next smallest at index 0 of value 16
# Now looking at group, prog
# Next smallest at index 4 of value 27
# Next smallest at index 4 of value 38
# Next smallest at index 4 of value 20
# Next smallest at index 4 of value 12
# Next smallest at index 4 of value 12
# Next smallest at index 4 of value 37
# Next smallest at index 4 of value 59
# Next smallest at index 4 of value 79
# Next smallest at index 4 of value 47
# Next smallest at index 4 of value 53
# Next smallest at index 4 of value 15
# Next smallest at index 4 of value 39
# Next smallest at index 4 of value 23
# Next smallest at index 4 of value 120
# Next smallest at index 4 of value 31
# Next smallest at index 4 of value 22
# Next smallest at index 4 of value 59
# Next smallest at index 4 of value 121
# Next smallest at index 4 of value 13
# Now looking at group, agy
# Next smallest at index 3 of value 18
# Next smallest at index 3 of value 24
# Next smallest at index 3 of value 28
# Next smallest at index 3 of value 69
# Next smallest at index 3 of value 66
# Next smallest at index 3 of value 46
# Next smallest at index 3 of value 63
# Next smallest at index 3 of value 20
# Next smallest at index 3 of value 37
# Next smallest at index 3 of value 15
# Next smallest at index 3 of value 20
# Next smallest at index 3 of value 17
# Next smallest at index 3 of value 53
# Next smallest at index 3 of value 85
# Next smallest at index 3 of value 16
# Now looking at group, age1
# Now looking at group, gender
# Next smallest at index 0 of value 1752
# Next smallest at index 0 of value 1752
# Next smallest at index 0 of value 560
# Next smallest at index 1 of value 1029
# Next smallest at index 0 of value 345
# Next smallest at index 0 of value 31490
# Now looking at group, fcage
# Next smallest at index 1 of value 17
# ...Processing column Asian_PI
# ...Processing column 3 departments
# ...Processing column CalWorks
# ...Processing column Hispanic
# ...Processing column Black
# ...Processing column 16 to 17
# ...Processing column 18 to 20
# ...Processing column 5+ programs
# ...Processing column 4 departments
# ...Processing column fileyear
# ...Processing column 18 and Over
# ...Processing column DDS
# ...Processing column 1 program
# ...Processing column 6 to 10
# ...Processing column 1 to 2
# ...Processing column IHSS
# ...Processing column Female
# ...Processing column 3 to 5
# ...Processing column 11 to 15
# ...Processing column 2 programs
# ...Processing column 18-64
# ...Processing column FPACT
# ...Processing column 3 programs
# ...Processing column 2 departments
# ...Processing column 4 programs
# ...Processing column 17 and Under
# ...Processing column WIC
# ...Processing column Child Welfare
# ...Processing column 1 department
# ...Processing column Native American/Other/Unknown
# ...Processing column Unknown/Other Gender
# ...Processing column age 0
# The next smallest value for column age 0 is at index 139 of value 13
# ...Processing column Male
# ...Processing column White
# ...Processing column CalFresh
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 3 of value 21
# Next smallest at index 3 of value 21
# Next smallest at index 2 of value 12
# Next smallest at index 0 of value 15
# Next smallest at index 1 of value 17
# Next smallest at index 1 of value 15
# Next smallest at index 4 of value 14
# Next smallest at index 2 of value 41
# Next smallest at index 0 of value 24
# Next smallest at index 2 of value 11
# Next smallest at index 0 of value 123
# Next smallest at index 0 of value 57
# Next smallest at index 0 of value 73
# Next smallest at index 1 of value 15
# Next smallest at index 0 of value 35
# Next smallest at index 0 of value 12
# Next smallest at index 0 of value 86
# Next smallest at index 1 of value 33
# Next smallest at index 0 of value 0
# Next smallest at index 0 of value 16
# Next smallest at index 3 of value 26
# Next smallest at index 0 of value 15
# Next smallest at index 1 of value 22
# Next smallest at index 3 of value 16
# Next smallest at index 0 of value 11
# Now looking at group, prog
# Next smallest at index 4 of value 47
# Next smallest at index 4 of value 19
# Next smallest at index 3 of value 13
# Next smallest at index 4 of value 67
# Next smallest at index 4 of value 46
# Next smallest at index 4 of value 16
# Next smallest at index 4 of value 48
# Next smallest at index 4 of value 13
# Next smallest at index 4 of value 43
# Next smallest at index 4 of value 32
# Next smallest at index 3 of value 20
# Next smallest at index 2 of value 12
# Next smallest at index 4 of value 32
# Next smallest at index 4 of value 36
# Next smallest at index 4 of value 16
# Next smallest at index 4 of value 34
# Next smallest at index 0 of value 0
# Next smallest at index 4 of value 31
# Next smallest at index 4 of value 28
# Next smallest at index 4 of value 90
# Next smallest at index 4 of value 12
# Next smallest at index 4 of value 12
# Next smallest at index 4 of value 67
# Next smallest at index 4 of value 39
# Next smallest at index 4 of value 21
# Now looking at group, agy
# Next smallest at index 3 of value 51
# Next smallest at index 2 of value 26
# Next smallest at index 3 of value 16
# Next smallest at index 2 of value 24
# Next smallest at index 3 of value 41
# Next smallest at index 3 of value 28
# Next smallest at index 3 of value 19
# Next smallest at index 3 of value 15
# Next smallest at index 1 of value 14
# Next smallest at index 1 of value 24
# Next smallest at index 3 of value 19
# Next smallest at index 2 of value 31
# Next smallest at index 2 of value 38
# Next smallest at index 1 of value 37
# Next smallest at index 3 of value 31
# Next smallest at index 3 of value 14
# Next smallest at index 3 of value 14
# Next smallest at index 3 of value 31
# Next smallest at index 0 of value 0
# Next smallest at index 3 of value 19
# Next smallest at index 3 of value 26
# Next smallest at index 3 of value 57
# Next smallest at index 2 of value 11
# Next smallest at index 3 of value 82
# Next smallest at index 3 of value 23
# Next smallest at index 3 of value 17
# Now looking at group, age1
# Next smallest at index 1 of value 0
# Next smallest at index 0 of value 41
# Next smallest at index 0 of value 33
# Next smallest at index 0 of value 79
# Next smallest at index 0 of value 69
# Next smallest at index 0 of value 11
# Next smallest at index 0 of value 41
# Next smallest at index 0 of value 13
# Next smallest at index 0 of value 26
# Next smallest at index 1 of value 0
# Next smallest at index 0 of value 51
# Next smallest at index 0 of value 42
# Next smallest at index 0 of value 34
# Next smallest at index 1 of value 0
# Next smallest at index 0 of value 89
# Next smallest at index 0 of value 41
# Now looking at group, gender
# Next smallest at index 0 of value 159
# Next smallest at index 0 of value 159
# Next smallest at index 0 of value 792
# Next smallest at index 0 of value 11141
# Next smallest at index 0 of value 49
# Next smallest at index 0 of value 1565
# Next smallest at index 1 of value 0
# Next smallest at index 0 of value 31490
# Now looking at group, fcage
# Next smallest at index 1 of value 36
# Next smallest at index 1 of value 19
# Next smallest at index 0 of value 0
# ...Processing column Asian_PI
# ...Processing column 3 departments
# ...Processing column CalWorks
# ...Processing column Hispanic
# ...Processing column Black
# ...Processing column 16 to 17
# ...Processing column 18 to 20
# ...Processing column 5+ programs
# ...Processing column 4 departments
# ...Processing column fileyear
# ...Processing column 18 and Over
# ...Processing column DDS
# ...Processing column 1 program
# ...Processing column 6 to 10
# ...Processing column 1 to 2
# ...Processing column IHSS
# ...Processing column Female
# ...Processing column 3 to 5
# ...Processing column 11 to 15
# ...Processing column 2 programs
# ...Processing column 18-64
# ...Processing column FPACT
# ...Processing column 3 programs
# ...Processing column 2 departments
# ...Processing column 4 programs
# ...Processing column 17 and Under
# ...Processing column WIC
# ...Processing column Child Welfare
# ...Processing column 1 department
# ...Processing column Native American/Other/Unknown
# ...Processing column Unknown/Other Gender
# ...Processing column age 0
# ...Processing column Male
# ...Processing column White
# ...Processing column CalFresh
# ...Processing column Medi-Cal

# %%
r.head()
# Out:
#    fileyear      Program           Level       Number Child Welfare Medi-Cal  \
# 0      2018  Foster Care  State Assembly           -9          3770     3552
# 1      2018  Foster Care  State Assembly  District 01           880      861
# 2      2018  Foster Care  State Assembly  District 02          1115     1087
# 3      2018  Foster Care  State Assembly  District 03          1185     1166
# 4      2018  Foster Care  State Assembly  District 04           624      606
#
#   FPACT CalFresh CalWorks IHSS  ... 18 to 20 1 program 2 programs 3 programs  \
# 0    45      684      597   *1  ...      333       161       1253       1196
# 1    15      265      172    0  ...      105        15        412        227
# 2    33      348      235    0  ...      116        20        504        309
# 3    31      349      221    0  ...      128        13        553        306
# 4    27      166      114    0  ...       83        13        297        180
#
#   4 programs 5+ programs 1 department 2 departments 3 departments  \
# 0        803         357          163          1625          1335
# 1        161          65           16           605           217
# 2        196          86           20           780           273
# 3        216          97           13           801           290
# 4         93          41           13           452           124
#
#   4 departments
# 0           647
# 1            42
# 2            42
# 3            81
# 4            35
#
# [5 rows x 39 columns]

# %%
r.to_excel('Dashboard_'+ year+"//"+"Masked_"+prog+"_Dashboard_" + year + ".xlsx",index=False)

# %% [markdown]
# # AUTOMATE TEST

# %% [markdown]
# ## Loop through Each Year and Mask

# %%
year = "18"

# %%
for filename in os.listdir('Dashboard_'+ year+"//"):
    if 'Masked' not in filename and 'test' not in filename:
        prog = filename.split('_')[0]
        if prog == 'CWS':
            prog = 'CWS_CMS'
        print("Processing",filename)
        t = pd.read_excel('Dashboard_'+ year+"//"+filename)
        group_dict = createGroupdict(prog)
        if year == '15':
            group_dict['agy'].remove('4 departments')
        v = batchMask(t,group_dict)
        v.to_excel('Dashboard_'+ year+"//Masked_"+filename)
# Out:
# Processing CalFresh_Dashboard_18.xlsx
# GEOGRAPHY level: State Assembly Total
# GEOGRAPHY level: State Senate Total
# GEOGRAPHY level: U.S. Congress Total
# GEOGRAPHY level: County Total
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column 60 and Over
# ...Processing column Child Welfare
# ...Processing column 18 to 59
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Cases
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column 60 and Over
# ...Processing column Child Welfare
# ...Processing column 18 to 59
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Cases
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column 60 and Over
# ...Processing column Child Welfare
# ...Processing column 18 to 59
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Cases
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 1 of value 16
# Next smallest at index 1 of value 17
# Next smallest at index 0 of value 54
# Now looking at group, prog
# Next smallest at index 0 of value 77
# Next smallest at index 3 of value 22
# Now looking at group, agy
# Next smallest at index 0 of value 25
# Next smallest at index 0 of value 78
# Next smallest at index 0 of value 107
# Next smallest at index 0 of value 81
# Next smallest at index 0 of value 42
# Next smallest at index 0 of value 55
# Next smallest at index 0 of value 73
# Next smallest at index 0 of value 66
# Now looking at group, age1
# Now looking at group, age2
# Next smallest at index 0 of value 74
# Now looking at group, gender
# ...Processing column 65 and Over
# The next smallest value for column 65 and Over is at index 204 of value 28
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# The next smallest value for column 3 departments is at index 224 of value 24
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# The next smallest value for column Native American/Other/Unknown is at index 180 of value 88
# ...Processing column FPACT
# The next smallest value for column FPACT is at index 200 of value 13
# ...Processing column Asian_PI
# ...Processing column Hispanic
# The next smallest value for column Hispanic is at index 224 of value 23
# ...Processing column 2 programs
# ...Processing column WIC
# The next smallest value for column WIC is at index 224 of value 24
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column 60 and Over
# ...Processing column Child Welfare
# ...Processing column 18 to 59
# ...Processing column CalWorks
# The next smallest value for column CalWorks is at index 224 of value 45
# ...Processing column 18-64
# ...Processing column Cases
# ...Processing column Black
# ...Processing column Medi-Cal
# Processing CalWorks_Dashboard_18.xlsx
# GEOGRAPHY level: State Assembly Total
# GEOGRAPHY level: State Senate Total
# GEOGRAPHY level: U.S. Congress Total
# GEOGRAPHY level: County Total
# Now looking at group, race
# Now looking at group, prog
# Next smallest at index 4 of value 103
# Next smallest at index 4 of value 434
# Next smallest at index 4 of value 635
# Next smallest at index 4 of value 602
# Next smallest at index 4 of value 508
# Next smallest at index 4 of value 583
# Next smallest at index 1 of value 732
# Next smallest at index 4 of value 439
# Next smallest at index 1 of value 333
# Next smallest at index 1 of value 231
# Next smallest at index 1 of value 358
# Next smallest at index 1 of value 333
# Next smallest at index 4 of value 220
# Next smallest at index 4 of value 326
# Next smallest at index 4 of value 186
# Next smallest at index 4 of value 243
# Next smallest at index 1 of value 319
# Now looking at group, agy
# Next smallest at index 3 of value 127
# Next smallest at index 3 of value 90
# Next smallest at index 3 of value 175
# Next smallest at index 3 of value 56
# Next smallest at index 3 of value 108
# Next smallest at index 3 of value 33
# Next smallest at index 3 of value 138
# Next smallest at index 3 of value 115
# Next smallest at index 3 of value 110
# Next smallest at index 3 of value 76
# Next smallest at index 3 of value 131
# Next smallest at index 3 of value 299
# Next smallest at index 3 of value 38
# Next smallest at index 3 of value 38
# Next smallest at index 2 of value 202
# Next smallest at index 3 of value 48
# Next smallest at index 3 of value 252
# Next smallest at index 2 of value 201
# Next smallest at index 3 of value 150
# Next smallest at index 3 of value 17
# Next smallest at index 3 of value 332
# Next smallest at index 3 of value 65
# Next smallest at index 3 of value 21
# Next smallest at index 3 of value 81
# Next smallest at index 3 of value 232
# Next smallest at index 3 of value 163
# Next smallest at index 3 of value 126
# Next smallest at index 3 of value 94
# Next smallest at index 3 of value 380
# Next smallest at index 3 of value 75
# Next smallest at index 3 of value 66
# Next smallest at index 3 of value 213
# Next smallest at index 3 of value 140
# Next smallest at index 3 of value 62
# Next smallest at index 3 of value 77
# Next smallest at index 3 of value 71
# Next smallest at index 3 of value 91
# Next smallest at index 3 of value 103
# Next smallest at index 3 of value 235
# Next smallest at index 3 of value 149
# Next smallest at index 3 of value 178
# Next smallest at index 3 of value 122
# Next smallest at index 3 of value 29
# Next smallest at index 3 of value 229
# Next smallest at index 3 of value 157
# Next smallest at index 3 of value 283
# Next smallest at index 3 of value 148
# Next smallest at index 3 of value 42
# Next smallest at index 3 of value 123
# Next smallest at index 3 of value 135
# Next smallest at index 3 of value 476
# Next smallest at index 3 of value 94
# Next smallest at index 3 of value 150
# Next smallest at index 3 of value 204
# Next smallest at index 3 of value 361
# Next smallest at index 3 of value 69
# Next smallest at index 3 of value 57
# Next smallest at index 3 of value 53
# Next smallest at index 3 of value 36
# Next smallest at index 3 of value 74
# Next smallest at index 3 of value 176
# Next smallest at index 3 of value 119
# Next smallest at index 3 of value 39
# Next smallest at index 2 of value 275
# Next smallest at index 3 of value 12
# Next smallest at index 3 of value 34
# Next smallest at index 3 of value 21
# Next smallest at index 3 of value 74
# Next smallest at index 3 of value 107
# Now looking at group, age1
# Now looking at group, age2
# Next smallest at index 0 of value 5925
# Next smallest at index 0 of value 5925
# Next smallest at index 0 of value 1893
# Next smallest at index 0 of value 3252
# Next smallest at index 0 of value 1109
# Next smallest at index 0 of value 3849
# Next smallest at index 0 of value 5206
# Next smallest at index 0 of value 2703
# Next smallest at index 0 of value 676
# Next smallest at index 0 of value 1964
# Next smallest at index 0 of value 2636
# Next smallest at index 0 of value 3338
# Next smallest at index 0 of value 1009
# Next smallest at index 0 of value 975
# Next smallest at index 0 of value 1811
# Next smallest at index 0 of value 378
# Next smallest at index 0 of value 942
# Next smallest at index 0 of value 4503
# Next smallest at index 0 of value 199
# Next smallest at index 0 of value 4283
# Next smallest at index 0 of value 479
# Next smallest at index 0 of value 5126
# Next smallest at index 0 of value 910
# Next smallest at index 0 of value 5203
# Next smallest at index 0 of value 3821
# Next smallest at index 0 of value 6528
# Next smallest at index 0 of value 3233
# Next smallest at index 0 of value 5806
# Next smallest at index 0 of value 873
# Next smallest at index 0 of value 2458
# Next smallest at index 0 of value 3273
# Next smallest at index 0 of value 1237
# Next smallest at index 0 of value 3087
# Next smallest at index 0 of value 2912
# Next smallest at index 0 of value 1537
# Next smallest at index 0 of value 2411
# Next smallest at index 0 of value 3647
# Next smallest at index 0 of value 2197
# Next smallest at index 0 of value 1370
# Next smallest at index 0 of value 524
# Next smallest at index 0 of value 2347
# Next smallest at index 0 of value 2623
# Next smallest at index 0 of value 2447
# Next smallest at index 0 of value 2024
# Next smallest at index 0 of value 730
# Next smallest at index 0 of value 4019
# Next smallest at index 0 of value 1903
# Next smallest at index 0 of value 2125
# Next smallest at index 0 of value 5598
# Next smallest at index 0 of value 1658
# Next smallest at index 0 of value 2953
# Next smallest at index 0 of value 2431
# Next smallest at index 0 of value 2710
# Next smallest at index 0 of value 5515
# Next smallest at index 0 of value 1521
# Next smallest at index 0 of value 975
# Next smallest at index 0 of value 1958
# Next smallest at index 0 of value 751
# Next smallest at index 0 of value 1434
# Next smallest at index 0 of value 2353
# Next smallest at index 0 of value 3458
# Next smallest at index 0 of value 1049
# Next smallest at index 0 of value 365
# Next smallest at index 0 of value 374
# Next smallest at index 0 of value 516
# Next smallest at index 0 of value 1370
# Next smallest at index 0 of value 2083
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column 18-64
# ...Processing column Cases
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Next smallest at index 4 of value 472
# Next smallest at index 4 of value 930
# Next smallest at index 4 of value 843
# Next smallest at index 4 of value 1203
# Next smallest at index 4 of value 1073
# Next smallest at index 1 of value 1363
# Next smallest at index 1 of value 523
# Next smallest at index 4 of value 766
# Next smallest at index 4 of value 324
# Next smallest at index 4 of value 571
# Next smallest at index 1 of value 655
# Next smallest at index 1 of value 772
# Next smallest at index 4 of value 320
# Next smallest at index 1 of value 839
# Now looking at group, agy
# Next smallest at index 3 of value 167
# Next smallest at index 3 of value 156
# Next smallest at index 3 of value 88
# Next smallest at index 3 of value 266
# Next smallest at index 3 of value 476
# Next smallest at index 3 of value 280
# Next smallest at index 3 of value 65
# Next smallest at index 3 of value 254
# Next smallest at index 3 of value 145
# Next smallest at index 3 of value 67
# Next smallest at index 3 of value 84
# Next smallest at index 3 of value 364
# Next smallest at index 3 of value 453
# Next smallest at index 3 of value 213
# Next smallest at index 3 of value 326
# Next smallest at index 3 of value 495
# Next smallest at index 3 of value 126
# Next smallest at index 3 of value 50
# Next smallest at index 3 of value 161
# Next smallest at index 3 of value 115
# Next smallest at index 3 of value 116
# Next smallest at index 3 of value 228
# Next smallest at index 3 of value 467
# Next smallest at index 3 of value 109
# Next smallest at index 3 of value 31
# Next smallest at index 3 of value 48
# Next smallest at index 3 of value 154
# Next smallest at index 3 of value 62
# Now looking at group, age1
# Now looking at group, age2
# Next smallest at index 0 of value 1633
# Next smallest at index 0 of value 1633
# Next smallest at index 0 of value 3065
# Next smallest at index 0 of value 2525
# Next smallest at index 0 of value 9016
# Next smallest at index 0 of value 1757
# Next smallest at index 0 of value 7126
# Next smallest at index 0 of value 2825
# Next smallest at index 0 of value 1457
# Next smallest at index 0 of value 1394
# Next smallest at index 0 of value 6713
# Next smallest at index 0 of value 432
# Next smallest at index 0 of value 1251
# Next smallest at index 0 of value 8618
# Next smallest at index 0 of value 4741
# Next smallest at index 0 of value 2679
# Next smallest at index 0 of value 10668
# Next smallest at index 0 of value 3853
# Next smallest at index 0 of value 6667
# Next smallest at index 0 of value 4278
# Next smallest at index 0 of value 1029
# Next smallest at index 0 of value 2182
# Next smallest at index 0 of value 4108
# Next smallest at index 0 of value 2375
# Next smallest at index 0 of value 4736
# Next smallest at index 0 of value 3756
# Next smallest at index 0 of value 2407
# Next smallest at index 0 of value 1001
# Next smallest at index 0 of value 1197
# Next smallest at index 0 of value 4130
# Next smallest at index 0 of value 1415
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column 18-64
# ...Processing column Cases
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Next smallest at index 4 of value 714
# Next smallest at index 4 of value 328
# Next smallest at index 4 of value 750
# Next smallest at index 4 of value 1024
# Next smallest at index 4 of value 695
# Next smallest at index 4 of value 736
# Next smallest at index 1 of value 710
# Next smallest at index 4 of value 674
# Next smallest at index 1 of value 505
# Next smallest at index 1 of value 514
# Next smallest at index 1 of value 589
# Next smallest at index 4 of value 468
# Next smallest at index 1 of value 753
# Next smallest at index 4 of value 360
# Now looking at group, agy
# Next smallest at index 3 of value 234
# Next smallest at index 3 of value 101
# Next smallest at index 3 of value 156
# Next smallest at index 3 of value 80
# Next smallest at index 3 of value 65
# Next smallest at index 3 of value 229
# Next smallest at index 3 of value 100
# Next smallest at index 3 of value 363
# Next smallest at index 3 of value 261
# Next smallest at index 3 of value 63
# Next smallest at index 3 of value 55
# Next smallest at index 3 of value 380
# Next smallest at index 3 of value 21
# Next smallest at index 3 of value 24
# Next smallest at index 3 of value 94
# Next smallest at index 3 of value 100
# Next smallest at index 3 of value 327
# Next smallest at index 3 of value 277
# Next smallest at index 3 of value 113
# Next smallest at index 3 of value 363
# Next smallest at index 3 of value 150
# Next smallest at index 3 of value 92
# Next smallest at index 3 of value 123
# Next smallest at index 3 of value 421
# Next smallest at index 3 of value 133
# Next smallest at index 3 of value 299
# Next smallest at index 3 of value 35
# Next smallest at index 3 of value 373
# Next smallest at index 3 of value 211
# Next smallest at index 3 of value 342
# Next smallest at index 3 of value 169
# Next smallest at index 3 of value 57
# Next smallest at index 3 of value 461
# Next smallest at index 3 of value 87
# Next smallest at index 3 of value 320
# Next smallest at index 3 of value 33
# Next smallest at index 3 of value 117
# Next smallest at index 3 of value 169
# Next smallest at index 3 of value 31
# Next smallest at index 3 of value 26
# Next smallest at index 3 of value 97
# Next smallest at index 3 of value 239
# Next smallest at index 3 of value 103
# Now looking at group, age1
# Now looking at group, age2
# Next smallest at index 0 of value 5925
# Next smallest at index 0 of value 5925
# Next smallest at index 0 of value 3819
# Next smallest at index 0 of value 2130
# Next smallest at index 0 of value 3564
# Next smallest at index 0 of value 1693
# Next smallest at index 0 of value 7145
# Next smallest at index 0 of value 4338
# Next smallest at index 0 of value 8172
# Next smallest at index 0 of value 4692
# Next smallest at index 0 of value 1554
# Next smallest at index 0 of value 1123
# Next smallest at index 0 of value 2104
# Next smallest at index 0 of value 443
# Next smallest at index 0 of value 1086
# Next smallest at index 0 of value 8383
# Next smallest at index 0 of value 606
# Next smallest at index 0 of value 1311
# Next smallest at index 0 of value 5655
# Next smallest at index 0 of value 6283
# Next smallest at index 0 of value 5951
# Next smallest at index 0 of value 5207
# Next smallest at index 0 of value 1381
# Next smallest at index 0 of value 1474
# Next smallest at index 0 of value 3611
# Next smallest at index 0 of value 4185
# Next smallest at index 0 of value 2167
# Next smallest at index 0 of value 5342
# Next smallest at index 0 of value 3432
# Next smallest at index 0 of value 635
# Next smallest at index 0 of value 3430
# Next smallest at index 0 of value 4019
# Next smallest at index 0 of value 4746
# Next smallest at index 0 of value 2885
# Next smallest at index 0 of value 1304
# Next smallest at index 0 of value 5056
# Next smallest at index 0 of value 4008
# Next smallest at index 0 of value 2216
# Next smallest at index 0 of value 4806
# Next smallest at index 0 of value 6569
# Next smallest at index 0 of value 831
# Next smallest at index 0 of value 2348
# Next smallest at index 0 of value 2785
# Next smallest at index 0 of value 957
# Next smallest at index 0 of value 2535
# Next smallest at index 0 of value 4478
# Next smallest at index 0 of value 521
# Next smallest at index 0 of value 2630
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column 18-64
# ...Processing column Cases
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 0 of value 0
# Next smallest at index 1 of value 11
# Next smallest at index 3 of value 47
# Next smallest at index 1 of value 103
# Next smallest at index 3 of value 26
# Next smallest at index 1 of value 30
# Next smallest at index 2 of value 11
# Now looking at group, prog
# Next smallest at index 4 of value 408
# Next smallest at index 4 of value 408
# Next smallest at index 0 of value 0
# Next smallest at index 4 of value 1067
# Next smallest at index 1 of value 12
# Next smallest at index 4 of value 157
# Next smallest at index 4 of value 12
# Next smallest at index 4 of value 784
# Next smallest at index 4 of value 1163
# Next smallest at index 4 of value 1203
# Next smallest at index 4 of value 1895
# Next smallest at index 4 of value 13
# Next smallest at index 4 of value 651
# Now looking at group, agy
# Next smallest at index 3 of value 167
# Next smallest at index 3 of value 167
# Next smallest at index 0 of value 0
# Next smallest at index 2 of value 121
# Next smallest at index 3 of value 82
# Next smallest at index 2 of value 198
# Next smallest at index 3 of value 95
# Next smallest at index 3 of value 19
# Next smallest at index 3 of value 392
# Next smallest at index 3 of value 35
# Next smallest at index 2 of value 69
# Next smallest at index 3 of value 66
# Next smallest at index 3 of value 27
# Next smallest at index 3 of value 55
# Next smallest at index 3 of value 18
# Next smallest at index 2 of value 85
# Next smallest at index 3 of value 109
# Next smallest at index 2 of value 81
# Next smallest at index 3 of value 68
# Next smallest at index 3 of value 12
# Next smallest at index 2 of value 183
# Next smallest at index 3 of value 19
# Next smallest at index 2 of value 56
# Next smallest at index 3 of value 373
# Next smallest at index 3 of value 80
# Next smallest at index 3 of value 134
# Next smallest at index 3 of value 77
# Next smallest at index 1 of value 24
# Next smallest at index 3 of value 55
# Next smallest at index 3 of value 237
# Next smallest at index 3 of value 30
# Next smallest at index 3 of value 35
# Next smallest at index 3 of value 342
# Next smallest at index 3 of value 162
# Next smallest at index 3 of value 28
# Now looking at group, age1
# Next smallest at index 0 of value 0
# Next smallest at index 0 of value 20
# Now looking at group, age2
# Next smallest at index 1 of value 0
# Next smallest at index 0 of value 1449
# Next smallest at index 0 of value 44
# Next smallest at index 0 of value 2463
# Next smallest at index 0 of value 9528
# Next smallest at index 0 of value 795
# Next smallest at index 0 of value 2165
# Next smallest at index 0 of value 6327
# Next smallest at index 0 of value 480
# Next smallest at index 0 of value 323
# Next smallest at index 0 of value 2593
# Next smallest at index 0 of value 6109
# Next smallest at index 0 of value 1335
# Next smallest at index 0 of value 355
# Next smallest at index 0 of value 2157
# Next smallest at index 1 of value 0
# Next smallest at index 0 of value 1784
# Next smallest at index 0 of value 784
# Next smallest at index 0 of value 4168
# Next smallest at index 0 of value 716
# Next smallest at index 0 of value 391
# Next smallest at index 0 of value 5144
# Next smallest at index 0 of value 1684
# Now looking at group, gender
# Next smallest at index 0 of value 0
# Next smallest at index 1 of value 16
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column Female
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# The next smallest value for column Person is at index 224 of value 26
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# The next smallest value for column CalFresh is at index 224 of value 24
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# The next smallest value for column 3 programs is at index 224 of value 22
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# The next smallest value for column Child Welfare is at index 192 of value 16
# ...Processing column 18 and Over
# ...Processing column 18-64
# ...Processing column Cases
# The next smallest value for column Cases is at index 224 of value 12
# ...Processing column Black
# ...Processing column Medi-Cal
# The next smallest value for column Medi-Cal is at index 224 of value 26
# Processing CWS_CMS_Dashboard_18.xlsx
# GEOGRAPHY level: State Assembly Total
# GEOGRAPHY level: State Senate Total
# GEOGRAPHY level: U.S. Congress Total
# GEOGRAPHY level: County Total
# Now looking at group, race
# Next smallest at index 0 of value 51
# Next smallest at index 1 of value 35
# Next smallest at index 0 of value 24
# Next smallest at index 0 of value 40
# Now looking at group, prog
# Next smallest at index 3 of value 35
# Now looking at group, agy
# Next smallest at index 2 of value 176
# Next smallest at index 2 of value 52
# Next smallest at index 2 of value 63
# Next smallest at index 2 of value 126
# Next smallest at index 2 of value 52
# Next smallest at index 2 of value 60
# Next smallest at index 2 of value 108
# Next smallest at index 2 of value 101
# Next smallest at index 2 of value 70
# Next smallest at index 2 of value 41
# Now looking at group, age1
# Next smallest at index 1 of value 358
# Next smallest at index 1 of value 708
# Next smallest at index 1 of value 758
# Next smallest at index 1 of value 530
# Next smallest at index 1 of value 170
# Next smallest at index 1 of value 216
# Next smallest at index 1 of value 363
# Next smallest at index 1 of value 224
# Next smallest at index 1 of value 1035
# Next smallest at index 1 of value 236
# Next smallest at index 1 of value 317
# Next smallest at index 1 of value 298
# Next smallest at index 1 of value 427
# Next smallest at index 1 of value 801
# Next smallest at index 1 of value 1433
# Next smallest at index 1 of value 1148
# Next smallest at index 1 of value 429
# Next smallest at index 1 of value 727
# Next smallest at index 1 of value 724
# Next smallest at index 1 of value 512
# Next smallest at index 1 of value 537
# Next smallest at index 1 of value 828
# Next smallest at index 1 of value 772
# Next smallest at index 1 of value 305
# Next smallest at index 1 of value 367
# Next smallest at index 1 of value 1174
# Next smallest at index 1 of value 698
# Next smallest at index 1 of value 669
# Next smallest at index 1 of value 445
# Next smallest at index 1 of value 780
# Next smallest at index 1 of value 537
# Next smallest at index 1 of value 1043
# Next smallest at index 1 of value 692
# Next smallest at index 1 of value 439
# Next smallest at index 1 of value 225
# Next smallest at index 1 of value 266
# Next smallest at index 1 of value 412
# Next smallest at index 1 of value 348
# Next smallest at index 1 of value 314
# Next smallest at index 1 of value 532
# Next smallest at index 1 of value 750
# Now looking at group, age2
# Next smallest at index 0 of value 14
# Next smallest at index 2 of value 11
# Next smallest at index 0 of value 15
# Next smallest at index 2 of value 23
# Next smallest at index 2 of value 15
# Next smallest at index 2 of value 16
# Next smallest at index 2 of value 15
# Next smallest at index 0 of value 14
# Next smallest at index 2 of value 16
# Next smallest at index 2 of value 37
# Next smallest at index 2 of value 18
# Next smallest at index 2 of value 11
# Next smallest at index 2 of value 15
# Next smallest at index 2 of value 16
# Next smallest at index 2 of value 14
# Next smallest at index 2 of value 11
# Next smallest at index 2 of value 12
# Next smallest at index 2 of value 14
# Next smallest at index 1 of value 219
# Next smallest at index 2 of value 12
# Next smallest at index 2 of value 15
# Now looking at group, gender
# Next smallest at index 0 of value 1361
# Next smallest at index 0 of value 1811
# Next smallest at index 0 of value 1766
# Next smallest at index 1 of value 1027
# Next smallest at index 1 of value 1363
# Next smallest at index 1 of value 451
# Next smallest at index 1 of value 1883
# Next smallest at index 1 of value 1319
# Next smallest at index 1 of value 1144
# Next smallest at index 1 of value 566
# Next smallest at index 1 of value 899
# Next smallest at index 0 of value 866
# Next smallest at index 1 of value 1643
# Next smallest at index 1 of value 723
# Next smallest at index 1 of value 908
# Next smallest at index 1 of value 1160
# Next smallest at index 1 of value 285
# Next smallest at index 1 of value 1494
# Next smallest at index 0 of value 303
# Next smallest at index 0 of value 411
# Next smallest at index 0 of value 1693
# Next smallest at index 1 of value 955
# Next smallest at index 0 of value 545
# Next smallest at index 0 of value 971
# Next smallest at index 0 of value 1701
# Next smallest at index 0 of value 1527
# Next smallest at index 1 of value 2710
# Next smallest at index 0 of value 1365
# Next smallest at index 1 of value 965
# Next smallest at index 1 of value 4373
# Next smallest at index 0 of value 777
# Next smallest at index 0 of value 1890
# Next smallest at index 0 of value 2149
# Next smallest at index 1 of value 864
# Next smallest at index 0 of value 1633
# Next smallest at index 0 of value 617
# Next smallest at index 1 of value 609
# Next smallest at index 1 of value 927
# Next smallest at index 1 of value 1501
# Next smallest at index 0 of value 1836
# Next smallest at index 1 of value 1474
# Next smallest at index 0 of value 864
# Next smallest at index 0 of value 1996
# Next smallest at index 1 of value 1555
# Next smallest at index 1 of value 2372
# Next smallest at index 1 of value 1519
# Next smallest at index 0 of value 1291
# Next smallest at index 1 of value 1272
# Next smallest at index 1 of value 1360
# Next smallest at index 1 of value 4265
# Next smallest at index 0 of value 854
# Next smallest at index 0 of value 1271
# Next smallest at index 1 of value 1533
# Next smallest at index 1 of value 1918
# Next smallest at index 1 of value 3688
# Next smallest at index 1 of value 540
# Next smallest at index 1 of value 876
# Next smallest at index 1 of value 1988
# Next smallest at index 1 of value 847
# Next smallest at index 0 of value 497
# Next smallest at index 0 of value 166
# Next smallest at index 0 of value 408
# Next smallest at index 1 of value 880
# Now looking at group, fcage
# Next smallest at index 1 of value 21
# Next smallest at index 1 of value 41
# Next smallest at index 1 of value 63
# Next smallest at index 1 of value 31
# Next smallest at index 1 of value 12
# Next smallest at index 1 of value 13
# Next smallest at index 1 of value 66
# Next smallest at index 1 of value 16
# Next smallest at index 1 of value 21
# Next smallest at index 1 of value 23
# Next smallest at index 1 of value 35
# Next smallest at index 1 of value 43
# Next smallest at index 1 of value 116
# Next smallest at index 1 of value 100
# Next smallest at index 6 of value 54
# Next smallest at index 1 of value 56
# Next smallest at index 1 of value 53
# Next smallest at index 1 of value 34
# Next smallest at index 6 of value 55
# Next smallest at index 1 of value 57
# Next smallest at index 1 of value 51
# Next smallest at index 1 of value 29
# Next smallest at index 1 of value 21
# Next smallest at index 1 of value 92
# Next smallest at index 1 of value 52
# Next smallest at index 1 of value 66
# Next smallest at index 1 of value 30
# Next smallest at index 1 of value 65
# Next smallest at index 1 of value 55
# Next smallest at index 1 of value 82
# Next smallest at index 1 of value 48
# Next smallest at index 1 of value 47
# Next smallest at index 1 of value 16
# Next smallest at index 1 of value 27
# Next smallest at index 1 of value 34
# Next smallest at index 1 of value 32
# Next smallest at index 2 of value 12
# Next smallest at index 1 of value 24
# Next smallest at index 1 of value 47
# Next smallest at index 1 of value 67
# ...Processing column age 0
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column age1 missing
# ...Processing column Native American/Other/Unknown
# ...Processing column 11 to 15
# ...Processing column 1 to 2
# ...Processing column 18 to 20
# ...Processing column FPACT
# ...Processing column 6 to 10
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 3 to 5
# ...Processing column 5+ programs
# The next smallest value for column 5+ programs is at index 16 of value 18
# ...Processing column 16 to 17
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column age2 missing
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column fc age missing
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Unknown/Other Gender
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Next smallest at index 1 of value 560
# Next smallest at index 1 of value 1406
# Next smallest at index 1 of value 572
# Next smallest at index 1 of value 824
# Next smallest at index 1 of value 960
# Next smallest at index 1 of value 544
# Now looking at group, age2
# Next smallest at index 2 of value 13
# Next smallest at index 2 of value 18
# Next smallest at index 2 of value 18
# Next smallest at index 2 of value 15
# Next smallest at index 2 of value 13
# Now looking at group, gender
# Next smallest at index 0 of value 2605
# Next smallest at index 1 of value 1677
# Next smallest at index 1 of value 2916
# Next smallest at index 0 of value 2754
# Next smallest at index 1 of value 3143
# Next smallest at index 1 of value 1135
# Next smallest at index 0 of value 2233
# Next smallest at index 1 of value 1894
# Next smallest at index 1 of value 964
# Next smallest at index 1 of value 1181
# Next smallest at index 0 of value 2652
# Next smallest at index 1 of value 616
# Next smallest at index 1 of value 1261
# Next smallest at index 0 of value 3745
# Next smallest at index 0 of value 1599
# Next smallest at index 1 of value 3374
# Next smallest at index 1 of value 1531
# Next smallest at index 1 of value 2464
# Next smallest at index 1 of value 3849
# Next smallest at index 1 of value 4043
# Next smallest at index 1 of value 1567
# Next smallest at index 1 of value 690
# Next smallest at index 1 of value 1340
# Next smallest at index 0 of value 1586
# Next smallest at index 0 of value 2145
# Next smallest at index 1 of value 2379
# Next smallest at index 1 of value 4834
# Next smallest at index 1 of value 1529
# Next smallest at index 1 of value 1128
# Next smallest at index 1 of value 730
# Next smallest at index 0 of value 2001
# Now looking at group, fcage
# Next smallest at index 1 of value 47
# Next smallest at index 1 of value 119
# Next smallest at index 1 of value 46
# Next smallest at index 1 of value 82
# Next smallest at index 1 of value 85
# Next smallest at index 1 of value 49
# ...Processing column age 0
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column age1 missing
# ...Processing column Native American/Other/Unknown
# ...Processing column 11 to 15
# ...Processing column 1 to 2
# ...Processing column 18 to 20
# ...Processing column FPACT
# ...Processing column 6 to 10
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 3 to 5
# ...Processing column 5+ programs
# ...Processing column 16 to 17
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column age2 missing
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column fc age missing
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Unknown/Other Gender
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Next smallest at index 2 of value 172
# Now looking at group, age1
# Next smallest at index 1 of value 1076
# Next smallest at index 1 of value 411
# Next smallest at index 1 of value 373
# Next smallest at index 1 of value 859
# Next smallest at index 1 of value 1013
# Next smallest at index 1 of value 942
# Next smallest at index 1 of value 341
# Next smallest at index 1 of value 446
# Next smallest at index 1 of value 1582
# Next smallest at index 1 of value 492
# Next smallest at index 1 of value 440
# Next smallest at index 1 of value 768
# Next smallest at index 1 of value 244
# Next smallest at index 1 of value 765
# Now looking at group, age2
# Next smallest at index 2 of value 31
# Next smallest at index 2 of value 11
# Next smallest at index 2 of value 23
# Next smallest at index 2 of value 18
# Next smallest at index 2 of value 14
# Next smallest at index 2 of value 15
# Next smallest at index 2 of value 12
# Now looking at group, gender
# Next smallest at index 0 of value 2368
# Next smallest at index 0 of value 1862
# Next smallest at index 0 of value 1857
# Next smallest at index 0 of value 1243
# Next smallest at index 1 of value 1300
# Next smallest at index 1 of value 2809
# Next smallest at index 1 of value 1358
# Next smallest at index 0 of value 3845
# Next smallest at index 1 of value 2137
# Next smallest at index 0 of value 1595
# Next smallest at index 1 of value 1125
# Next smallest at index 1 of value 986
# Next smallest at index 1 of value 1378
# Next smallest at index 1 of value 541
# Next smallest at index 1 of value 2721
# Next smallest at index 0 of value 517
# Next smallest at index 1 of value 1351
# Next smallest at index 0 of value 1171
# Next smallest at index 0 of value 2018
# Next smallest at index 1 of value 1894
# Next smallest at index 0 of value 2714
# Next smallest at index 1 of value 1157
# Next smallest at index 0 of value 4252
# Next smallest at index 1 of value 1002
# Next smallest at index 1 of value 1140
# Next smallest at index 0 of value 1120
# Next smallest at index 1 of value 3152
# Next smallest at index 1 of value 1239
# Next smallest at index 1 of value 3191
# Next smallest at index 1 of value 2194
# Next smallest at index 1 of value 406
# Next smallest at index 1 of value 3382
# Next smallest at index 1 of value 2201
# Next smallest at index 0 of value 1967
# Next smallest at index 1 of value 3178
# Next smallest at index 1 of value 1873
# Next smallest at index 1 of value 3971
# Next smallest at index 0 of value 1806
# Next smallest at index 1 of value 1044
# Next smallest at index 1 of value 3297
# Next smallest at index 1 of value 2103
# Next smallest at index 1 of value 563
# Next smallest at index 1 of value 899
# Next smallest at index 0 of value 1727
# Next smallest at index 0 of value 315
# Next smallest at index 1 of value 915
# Now looking at group, fcage
# Next smallest at index 1 of value 98
# Next smallest at index 1 of value 23
# Next smallest at index 1 of value 27
# Next smallest at index 6 of value 93
# Next smallest at index 1 of value 71
# Next smallest at index 1 of value 72
# Next smallest at index 1 of value 34
# Next smallest at index 1 of value 41
# Next smallest at index 1 of value 138
# Next smallest at index 1 of value 55
# Next smallest at index 1 of value 37
# Next smallest at index 1 of value 64
# Next smallest at index 1 of value 22
# Next smallest at index 1 of value 63
# ...Processing column age 0
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# The next smallest value for column 4 departments is at index 142 of value 11
# ...Processing column age1 missing
# ...Processing column Native American/Other/Unknown
# ...Processing column 11 to 15
# ...Processing column 1 to 2
# ...Processing column 18 to 20
# ...Processing column FPACT
# ...Processing column 6 to 10
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 3 to 5
# ...Processing column 5+ programs
# ...Processing column 16 to 17
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column age2 missing
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column fc age missing
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Unknown/Other Gender
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 1 of value 75
# Next smallest at index 1 of value 40
# Next smallest at index 1 of value 52
# Next smallest at index 3 of value 18
# Next smallest at index 3 of value 11
# Next smallest at index 1 of value 21
# Next smallest at index 2 of value 13
# Next smallest at index 1 of value 21
# Next smallest at index 4 of value 14
# Next smallest at index 1 of value 11
# Next smallest at index 1 of value 39
# Next smallest at index 1 of value 15
# Now looking at group, prog
# Next smallest at index 3 of value 24
# Next smallest at index 3 of value 13
# Next smallest at index 3 of value 12
# Next smallest at index 3 of value 15
# Next smallest at index 3 of value 21
# Now looking at group, agy
# Next smallest at index 2 of value 28
# Next smallest at index 2 of value 37
# Next smallest at index 2 of value 17
# Next smallest at index 0 of value 52
# Next smallest at index 2 of value 50
# Next smallest at index 0 of value 30
# Next smallest at index 2 of value 23
# Next smallest at index 2 of value 116
# Next smallest at index 0 of value 17
# Next smallest at index 2 of value 50
# Next smallest at index 2 of value 39
# Next smallest at index 2 of value 31
# Next smallest at index 2 of value 16
# Next smallest at index 2 of value 30
# Next smallest at index 2 of value 21
# Next smallest at index 0 of value 50
# Now looking at group, age1
# Next smallest at index 1 of value 67
# Next smallest at index 1 of value 112
# Next smallest at index 1 of value 123
# Next smallest at index 1 of value 116
# Next smallest at index 1 of value 26
# Next smallest at index 1 of value 77
# Next smallest at index 1 of value 30
# Next smallest at index 1 of value 79
# Next smallest at index 1 of value 86
# Next smallest at index 1 of value 48
# Next smallest at index 2 of value 12
# Next smallest at index 1 of value 121
# Next smallest at index 1 of value 199
# Next smallest at index 1 of value 55
# Next smallest at index 1 of value 99
# Now looking at group, age2
# Next smallest at index 0 of value 0
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 23
# Next smallest at index 0 of value 37
# Next smallest at index 1 of value 65
# Next smallest at index 0 of value 12
# Next smallest at index 0 of value 16
# Next smallest at index 1 of value 102
# Next smallest at index 0 of value 19
# Next smallest at index 0 of value 13
# Next smallest at index 1 of value 45
# Next smallest at index 0 of value 34
# Next smallest at index 0 of value 52
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 27
# Next smallest at index 0 of value 59
# Next smallest at index 0 of value 47
# Next smallest at index 0 of value 21
# Next smallest at index 0 of value 26
# Next smallest at index 1 of value 161
# Next smallest at index 0 of value 38
# Next smallest at index 0 of value 16
# Next smallest at index 0 of value 22
# Next smallest at index 0 of value 11
# Now looking at group, gender
# Next smallest at index 0 of value 89
# Next smallest at index 0 of value 841
# Next smallest at index 0 of value 137
# Next smallest at index 0 of value 444
# Next smallest at index 0 of value 2952
# Next smallest at index 0 of value 816
# Next smallest at index 0 of value 654
# Next smallest at index 0 of value 507
# Next smallest at index 0 of value 242
# Next smallest at index 0 of value 479
# Next smallest at index 0 of value 178
# Next smallest at index 1 of value 35
# Next smallest at index 0 of value 383
# Next smallest at index 0 of value 852
# Next smallest at index 0 of value 692
# Next smallest at index 1 of value 262
# Next smallest at index 0 of value 102
# Next smallest at index 0 of value 464
# Next smallest at index 0 of value 109
# Next smallest at index 1 of value 566
# Next smallest at index 0 of value 667
# Next smallest at index 0 of value 400
# Next smallest at index 0 of value 636
# Next smallest at index 0 of value 133
# Next smallest at index 0 of value 728
# Next smallest at index 0 of value 1016
# Next smallest at index 0 of value 268
# Next smallest at index 0 of value 61
# Next smallest at index 0 of value 126
# Next smallest at index 0 of value 1240
# Next smallest at index 0 of value 748
# Next smallest at index 0 of value 302
# Now looking at group, fcage
# Next smallest at index 2 of value 17
# ...Processing column age 0
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# The next smallest value for column 2 departments is at index 225 of value 13
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column age1 missing
# ...Processing column Native American/Other/Unknown
# ...Processing column 11 to 15
# ...Processing column 1 to 2
# ...Processing column 18 to 20
# ...
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Black
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 2 of value 19
# Next smallest at index 3 of value 16
# Next smallest at index 2 of value 12
# Next smallest at index 0 of value 13
# Next smallest at index 3 of value 14
# Next smallest at index 0 of value 18
# Now looking at group, prog
# Next smallest at index 1 of value 21
# Next smallest at index 4 of value 15
# Next smallest at index 0 of value 46
# Next smallest at index 4 of value 11
# Next smallest at index 3 of value 34
# Next smallest at index 3 of value 19
# Next smallest at index 2 of value 95
# Next smallest at index 3 of value 13
# Next smallest at index 0 of value 20
# Next smallest at index 0 of value 12
# Next smallest at index 0 of value 11
# Next smallest at index 0 of value 24
# Next smallest at index 4 of value 11
# Now looking at group, agy
# Next smallest at index 1 of value 24
# Next smallest at index 2 of value 64
# Next smallest at index 3 of value 24
# Next smallest at index 3 of value 21
# Next smallest at index 2 of value 48
# Next smallest at index 0 of value 11
# Next smallest at index 2 of value 29
# Next smallest at index 2 of value 199
# Next smallest at index 3 of value 23
# Next smallest at index 2 of value 37
# Next smallest at index 0 of value 22
# Next smallest at index 3 of value 11
# Next smallest at index 0 of value 12
# Next smallest at index 3 of value 14
# Next smallest at index 1 of value 35
# Next smallest at index 2 of value 22
# Next smallest at index 3 of value 32
# Next smallest at index 2 of value 74
# Next smallest at index 2 of value 129
# Now looking at group, age1
# Next smallest at index 1 of value 25
# Next smallest at index 1 of value 128
# Next smallest at index 1 of value 113
# Next smallest at index 1 of value 27
# Next smallest at index 1 of value 344
# Next smallest at index 1 of value 36
# Next smallest at index 1 of value 208
# Now looking at group, age2
# Now looking at group, gender
# Next smallest at index 0 of value 22
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# The next smallest value for column White is at index 204 of value 21
# ...Processing column 1 program
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# The next smallest value for column Male is at index 224 of value 12
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Black
# ...Processing column Medi-Cal
# Processing Medical_Dashboard_18.xlsx
# GEOGRAPHY level: State Assembly Total
# GEOGRAPHY level: State Senate Total
# GEOGRAPHY level: U.S. Congress Total
# GEOGRAPHY level: County Total
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column ACA
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Black
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# The next smallest value for column IHSS is at index 121 of value 15
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column ACA
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Black
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column ACA
# ...Processing column CalFresh
# ...Processing column WIC
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Black
# Now looking at group, race
# Next smallest at index 2 of value 11
# Next smallest at index 3 of value 172
# Now looking at group, prog
# Next smallest at index 2 of value 23
# Next smallest at index 3 of value 113
# Next smallest at index 3 of value 14
# Now looking at group, agy
# Next smallest at index 2 of value 282
# Next smallest at index 2 of value 474
# Next smallest at index 2 of value 244
# Next smallest at index 2 of value 157
# Next smallest at index 2 of value 32
# Next smallest at index 2 of value 300
# Next smallest at index 2 of value 29
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column 65 and Over
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 1 program
# ...Processing column IHSS
# ...Processing column 17 and Under
# ...Processing column 2 departments
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column FPACT
# The next smallest value for column FPACT is at index 232 of value 14
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column 2 programs
# ...Processing column ACA
# ...Processing column CalFresh
# ...Processing column WIC
# The next smallest value for column WIC is at index 181 of value 21
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# The next smallest value for column Child Welfare is at index 181 of value 14
# ...Processing column 18 and Over
# ...Processing column CalWorks
# ...Processing column 18-64
# ...Processing column Female
# ...Processing column Black
# Processing WIC_Dashboard_18.xlsx
# GEOGRAPHY level: State Assembly Total
# GEOGRAPHY level: State Senate Total
# GEOGRAPHY level: U.S. Congress Total
# GEOGRAPHY level: County Total
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column wic age 3
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 30 to 34
# ...Processing column 1 program
# ...Processing column wic age 1
# ...Processing column IHSS
# ...Processing column 20 to 24
# ...Processing column 2 departments
# ...Processing column 25 to 29
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column wic age 0
# ...Processing column 35 and over
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column wic age 20 and Over
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column wic age 4
# ...Processing column less than 19
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column CalWorks
# ...Processing column wic age 2
# ...Processing column Female
# ...Processing column Unknown/Other Gender
# ...Processing column Black
# ...Processing column wic age 5 to 19
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column wic age 3
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 30 to 34
# ...Processing column 1 program
# ...Processing column wic age 1
# ...Processing column IHSS
# ...Processing column 20 to 24
# ...Processing column 2 departments
# ...Processing column 25 to 29
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column wic age 0
# ...Processing column 35 and over
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column wic age 20 and Over
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column wic age 4
# ...Processing column less than 19
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column CalWorks
# ...Processing column wic age 2
# ...Processing column Female
# ...Processing column Unknown/Other Gender
# ...Processing column Black
# ...Processing column wic age 5 to 19
# ...Processing column Medi-Cal
# Now looking at group, race
# Now looking at group, prog
# Now looking at group, agy
# Now looking at group, age1
# Now looking at group, age2
# Now looking at group, gender
# ...Processing column wic age 3
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 30 to 34
# ...Processing column 1 program
# ...Processing column wic age 1
# ...Processing column IHSS
# ...Processing column 20 to 24
# ...Processing column 2 departments
# ...Processing column 25 to 29
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column wic age 0
# ...Processing column 35 and over
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column wic age 20 and Over
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column wic age 4
# ...Processing column less than 19
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column CalWorks
# ...Processing column wic age 2
# ...Processing column Female
# ...Processing column Unknown/Other Gender
# ...Processing column Black
# ...Processing column wic age 5 to 19
# ...Processing column Medi-Cal
# Now looking at group, race
# Next smallest at index 3 of value 24
# Next smallest at index 0 of value 61
# Next smallest at index 0 of value 35
# Next smallest at index 4 of value 17
# Next smallest at index 3 of value 55
# Next smallest at index 0 of value 12
# Next smallest at index 4 of value 124
# Next smallest at index 3 of value 53
# Next smallest at index 2 of value 22
# Next smallest at index 0 of value 19
# Next smallest at index 2 of value 34
# Now looking at group, prog
# Next smallest at index 1 of value 14
# Next smallest at index 0 of value 31
# Next smallest at index 0 of value 21
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 54
# Now looking at group, agy
# Next smallest at index 0 of value 21
# Next smallest at index 0 of value 18
# Next smallest at index 0 of value 13
# Next smallest at index 0 of value 15
# Now looking at group, age1
# Next smallest at index 4 of value 11
# Next smallest at index 1 of value 16
# Now looking at group, age2
# Next smallest at index 3 of value 84
# Next smallest at index 4 of value 37
# Next smallest at index 2 of value 40
# Next smallest at index 4 of value 82
# Next smallest at index 4 of value 107
# Next smallest at index 2 of value 45
# Next smallest at index 4 of value 37
# Now looking at group, gender
# ...Processing column wic age 3
# ...Processing column Foster Care
# ...Processing column DDS
# ...Processing column White
# ...Processing column 30 to 34
# ...Processing column 1 program
# ...Processing column wic age 1
# The next smallest value for column wic age 1 is at index 225 of value 17
# ...Processing column IHSS
# ...Processing column 20 to 24
# ...Processing column 2 departments
# ...Processing column 25 to 29
# ...Processing column 3 departments
# ...Processing column Person
# ...Processing column fileyear
# ...Processing column wic age 0
# ...Processing column 35 and over
# ...Processing column 4 departments
# ...Processing column Native American/Other/Unknown
# ...Processing column wic age 20 and Over
# ...Processing column FPACT
# ...Processing column Asian_PI
# ...Processing column Hispanic
# ...Processing column wic age 4
# ...Processing column less than 19
# ...Processing column 2 programs
# ...Processing column CalFresh
# ...Processing column 5+ programs
# ...Processing column 1 department
# ...Processing column 3 programs
# ...Processing column 4 programs
# ...Processing column Male
# ...Processing column Child Welfare
# ...Processing column CalWorks
# ...Processing column wic age 2
# ...Processing column Female
# ...Processing column Unknown/Other Gender
# ...Processing column Black
# ...Processing column wic age 5 to 19
# ...Processing column Medi-Cal

# %% [markdown]
# ## Stacking

# %%
ls = []
df_ls = []
for filename in os.listdir('Dashboard_'+ year+"//"):
    if 'Masked' in filename and 'zip' not in filename:
        print(filename)
        ls.append(filename)
        df_ls.append(pd.read_excel('Dashboard_'+ year+"//"+filename))
# Out:
# Masked_CalFresh_Dashboard_18.xlsx
# Masked_CalWorks_Dashboard_18.xlsx
# Masked_CWS_CMS_Dashboard_18.xlsx
# Masked_DDS_Dashboard_18.xlsx
# Masked_FC_Dashboard_18.xlsx
# Masked_FPACT_Dashboard_18.xlsx
# Masked_IHSS_Dashboard_18.xlsx
# Masked_Medical_Dashboard_18.xlsx
# Masked_WIC_Dashboard_18.xlsx

# %%
df = pd.concat(df_ls,axis=0,sort=False)

# %%
correct_order = ['fileyear','Program','Level','Number','Person','Cases','Medi-Cal','ACA',
                 'FPACT','CalFresh','CalWorks','IHSS','Child Welfare','Foster Care','DDS',
                 'WIC','Black','White','Hispanic','Asian_PI','Native American/Other/Unknown'
                 ,'Female','Male','Unknown/Other Gender','age1 missing','17 and Under',
                 '18 and Over','age2 missing','18-64','65 and Over','18 to 59','60 and Over',
                 '1 program','2 programs','3 programs','4 programs','5+ programs','1 department',
                 '2 departments','3 departments','4 departments','fc age missing',
                 'age 0','1 to 2','3 to 5','6 to 10','11 to 15','16 to 17','18 to 20','less than 19',
                 '20 to 24','25 to 29','30 to 34','35 and over','wic age 0','wic age 1','wic age 2',
                 'wic age 3','wic age 4','wic age 5 to 19','wic age 20 and Over']
if year =='15':
    correct_order.remove('4 departments')

# %%
df = df[correct_order]

# %%
df.to_excel('Dashboard_'+ year+"//"+"Test_stacked_"+year+".xlsx")

# %%
#********************************END OF CODE***********************************#
