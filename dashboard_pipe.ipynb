# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### FUNCTION INVENTORY ###

# %%
def verticalMask(df, drop_cols = ['Program', 'Level', 'Number']):
    '''Asssuming the dataframe only contains 1 geography,
    iterrate through each column to perform vertical masking
    :param df: Dataframe
    :param drop_cols: list of columns to NOT be masked/ignored
    '''
    d = df.copy()
    #Iteratate through every report column
    cols = list(set(d.columns.tolist()) - set(drop_cols))
    
    for c in cols:
        print("...Processing",c)
        #Only mask if a single number in that column is -999
#         print(np.sum(d.loc[d[c] < 0, c]))
        if sum(d.loc[d[c] < 0, c]) == -999: 
            #Find the next smallest number and change it to 20
            next_min_idx = np.argmin(d.loc[d[c] >= 0 , c])
            next_min = np.min(d.loc[d[c] >= 0 , c])
            print("The next smallest value for column {} is at index {} of value {}".format(c,next_min_idx,next_min))
            #Secondary mask 
            d.loc[next_min_idx, c] = -100
    return d

# %%
def secondMask(row):
    '''
    Pass a vector in, mask if only one -999 value
    :param row: a numpy vector
    '''
    if len(row[row ==  -999]) == 1:
#         print("Row before:\n", row)
        next_min = np.min(row[row >= 0])
        next_min_idx = np.where(row==next_min)[0][0]

        print("Next smallest at index {} of value {}".format(next_min_idx, next_min))
        #Mask
        row[next_min_idx] = -100
#         print("Row after:\n", row)
    return row

# %%
def horizontalMask(df, grp:dict):
    '''
    Leveraging the secondMask function, change the 
    group of related column names, then perform masking 
    within the parameters for each row in group. 
    :param df: Pandas dataframe
    :grp: dictionary of gorup names
    '''
    d = df.copy()
    for k,v in grp.items():
        d.loc[:,v] = d.loc[:,v].apply(secondMask, axis=1)
    return d

# %%
def splitReport(df:pd.DataFrame, geo=["State Assembly Total","State Senate Total"
                                      ,"U.S. Congress Total"
                                     ,"County Total"]):
    '''
    Accept a DF that is the original Excel report,
    split into N sub-reports based on geographies as 
    lited by the geo parameters
    '''
    #We can identify each section of the report here...
    indices = np.zeros(len(geo),dtype='int')
    split_dfs = []
    for idx in range(len(geo)): 
        indices[idx] = df.index[df.Number == geo[idx]].tolist()[0]
        if idx == 0:
            split_dfs.append(df.iloc[:indices[idx]+1])
        else:
            split_dfs.append(df.iloc[indices[idx-1]+1:indices[idx]+1])
    return split_dfs

# %%
def batchMask(df, grp):
    masked_df = splitReport(df)
    final_df = pd.DataFrame()
    for i in range(len(masked_df)):
        #Horizontal masking
        masked_df[i] = horizontalMask(masked_df[i], grp)
        #Vertical masking
        masked_df[i] = verticalMask(masked_df[i])
        #Concatenate
        final_df = pd.concat([final_df, masked_df[i]])
    
    if ! assert df.shape == final_df.shape: 
        print("Final dataframe does NOT preserve original shape!!")
    return final_df
# Out:
#   File "<ipython-input-49-30d06e9310e1>", line 12
#     if ! assert df.shape == final_df.shape:
#        ^
# SyntaxError: invalid syntax

# %%
group_dict = dict()
group_dict["race"] = ['Other/Unknown','Black', 'White', 'Hispanic', 'Asian_PI', 'Native_American']
group_dict["gender"] = ['Female','Male', 'Unknown/Other Gender']
group_dict["prog"] = ['1 program', '2 programs', '3 programs','4 programs', '5+ programs']
group_dict["agy"] = ['1 department', '2 departments','3 departments', '4 departments']
group_dict["age1"] = ['17 and Under', '18 and Over', '18-64','65 and Over']
group_dict["age2"] = ['age 0', '1 to 2', '3 to 5', '6 to 10', '11 to 15','16 to 17', '18 to 21']

# %% [markdown]
# ## PRODUCTION TEST

# %%
d = pd.read_excel("CWS_CMS_Dashboard_16.xlsx")

# %%
r = batchMask(d, group_dict)
# Out:
# Next smallest at index 0 of value 74
# Next smallest at index 0 of value 43
# Next smallest at index 0 of value 74
# Next smallest at index 0 of value 26
# Next smallest at index 0 of value 20
# Next smallest at index 0 of value 51
# Next smallest at index 4 of value 43
# Next smallest at index 0 of value 176
# Next smallest at index 0 of value 130
# Next smallest at index 0 of value 102
# Next smallest at index 4 of value 45
# Next smallest at index 0 of value 137
# Next smallest at index 0 of value 176
# Next smallest at index 0 of value 120
# Next smallest at index 0 of value 57
# Next smallest at index 4 of value 109
# Next smallest at index 0 of value 44
# Next smallest at index 4 of value 139
# Next smallest at index 0 of value 36
# Next smallest at index 0 of value 25
# Next smallest at index 0 of value 51
# Next smallest at index 0 of value 38
# Next smallest at index 0 of value 24
# Next smallest at index 1 of value 2996
# Next smallest at index 1 of value 1699
# Next smallest at index 1 of value 2760
# Next smallest at index 0 of value 988
# Next smallest at index 0 of value 3538
# Next smallest at index 0 of value 2239
# Next smallest at index 1 of value 1338
# Next smallest at index 0 of value 1591
# Next smallest at index 0 of value 1620
# Next smallest at index 0 of value 2442
# Next smallest at index 0 of value 1446
# Next smallest at index 0 of value 457
# Next smallest at index 1 of value 1899
# Next smallest at index 1 of value 2340
# Next smallest at index 1 of value 801
# Next smallest at index 1 of value 1154
# Next smallest at index 0 of value 3013
# Next smallest at index 1 of value 863
# Next smallest at index 1 of value 1862
# Next smallest at index 1 of value 1027
# Next smallest at index 1 of value 1198
# Next smallest at index 1 of value 2941
# Next smallest at index 1 of value 1342
# Next smallest at index 1 of value 1225
# Next smallest at index 0 of value 2096
# Next smallest at index 0 of value 2848
# Next smallest at index 0 of value 2843
# Next smallest at index 0 of value 4003
# Next smallest at index 0 of value 2396
# Next smallest at index 1 of value 1943
# Next smallest at index 1 of value 1186
# Next smallest at index 0 of value 2071
# Next smallest at index 0 of value 4838
# Next smallest at index 0 of value 3065
# Next smallest at index 1 of value 1964
# Next smallest at index 0 of value 3364
# Next smallest at index 1 of value 1390
# Next smallest at index 1 of value 1248
# Next smallest at index 0 of value 2376
# Next smallest at index 0 of value 4218
# Next smallest at index 1 of value 2878
# Next smallest at index 1 of value 1989
# Next smallest at index 1 of value 825
# Next smallest at index 0 of value 4475
# Next smallest at index 0 of value 3249
# Next smallest at index 1 of value 906
# Next smallest at index 0 of value 2553
# Next smallest at index 0 of value 2673
# Next smallest at index 1 of value 3427
# Next smallest at index 0 of value 1717
# Next smallest at index 1 of value 4457
# Next smallest at index 1 of value 1365
# Next smallest at index 1 of value 1243
# Next smallest at index 0 of value 2043
# Next smallest at index 0 of value 923
# Next smallest at index 1 of value 2047
# Next smallest at index 1 of value 4553
# Next smallest at index 1 of value 1938
# Next smallest at index 1 of value 1223
# Next smallest at index 1 of value 1163
# Next smallest at index 0 of value 917
# Next smallest at index 1 of value 1462
# Next smallest at index 1 of value 2219
# Next smallest at index 2 of value 61
# Next smallest at index 2 of value 126
# Next smallest at index 2 of value 102
# Next smallest at index 0 of value 1199
# Next smallest at index 0 of value 345
# Next smallest at index 0 of value 1059
# Next smallest at index 0 of value 1273
# Next smallest at index 0 of value 1125
# Next smallest at index 0 of value 1865
# Next smallest at index 0 of value 902
# Next smallest at index 2 of value 914
# Next smallest at index 0 of value 975
# Next smallest at index 0 of value 504
# Next smallest at index 0 of value 513
# Next smallest at index 0 of value 362
# Next smallest at index 0 of value 797
# ...Processing Black
# ...Processing 18 and Over
# ...Processing Foster Care
# ...Processing 6 to 10
# ...Processing Native_American
# ...Processing 11 to 15
# ...Processing 2 departments
# ...Processing 4 departments
# ...Processing Other/Unknown
# ...Processing 1 to 2
# ...Processing CalWorks
# ...Processing 17 and Under
# ...Processing Unknown/Other Gender
# ...Processing WIC
# ...Processing 2 programs
# ...Processing Hispanic
# ...Processing 18 to 21
# ...Processing 1 department
# ...Processing CalFresh
# ...Processing Female
# ...Processing 16 to 17
# ...Processing Male
# ...Processing 65 and Over
# ...Processing 3 to 5
# ...Processing FPACT
# ...Processing 4 programs
# ...Processing 1 program
# ...Processing 3 programs
# ...Processing Medi-Cal
# ...Processing 5+ programs
# ...Processing 3 departments
# ...Processing Asian_PI
# ...Processing IHSS
# ...Processing White
# ...Processing 18-64
# ...Processing DDS
# ...Processing age 0
# ...Processing Person
# Next smallest at index 0 of value 189
# Next smallest at index 0 of value 77
# Next smallest at index 0 of value 49
# Next smallest at index 0 of value 2800
# Next smallest at index 1 of value 5418
# Next smallest at index 1 of value 2127
# Next smallest at index 0 of value 4149
# Next smallest at index 1 of value 3663
# Next smallest at index 1 of value 2379
# Next smallest at index 1 of value 2703
# Next smallest at index 1 of value 1881
# Next smallest at index 1 of value 4046
# Next smallest at index 0 of value 3285
# Next smallest at index 1 of value 3385
# Next smallest at index 1 of value 5229
# Next smallest at index 1 of value 1544
# Next smallest at index 0 of value 3302
# Next smallest at index 1 of value 2393
# Next smallest at index 1 of value 2971
# Next smallest at index 1 of value 1674
# Next smallest at index 1 of value 1481
# Next smallest at index 1 of value 2659
# Next smallest at index 0 of value 1574
# Next smallest at index 0 of value 4403
# ...Processing Black
# ...Processing 18 and Over
# ...Processing Foster Care
# ...Processing 6 to 10
# ...Processing Native_American
# ...Processing 11 to 15
# ...Processing 2 departments
# ...Processing 4 departments
# ...Processing Other/Unknown
# ...Processing 1 to 2
# ...Processing CalWorks
# ...Processing 17 and Under
# ...Processing Unknown/Other Gender
# ...Processing WIC
# ...Processing 2 programs
# ...Processing Hispanic
# ...Processing 18 to 21
# ...Processing 1 department
# ...Processing CalFresh
# ...Processing Female
# ...Processing 16 to 17
# ...Processing Male
# ...Processing 65 and Over
# ...Processing 3 to 5
# ...Processing FPACT
# ...Processing 4 programs
# ...Processing 1 program
# ...Processing 3 programs
# ...Processing Medi-Cal
# ...Processing 5+ programs
# ...Processing 3 departments
# ...Processing Asian_PI
# ...Processing IHSS
# ...Processing White
# ...Processing 18-64
# ...Processing DDS
# ...Processing age 0
# ...Processing Person
# Next smallest at index 0 of value 36
# Next smallest at index 4 of value 80
# Next smallest at index 0 of value 164
# Next smallest at index 0 of value 188
# Next smallest at index 0 of value 27
# Next smallest at index 0 of value 80
# Next smallest at index 0 of value 34
# Next smallest at index 0 of value 3103
# Next smallest at index 0 of value 2765
# Next smallest at index 1 of value 3272
# Next smallest at index 0 of value 3078
# Next smallest at index 1 of value 2022
# Next smallest at index 1 of value 2143
# Next smallest at index 1 of value 2777
# Next smallest at index 1 of value 1518
# Next smallest at index 1 of value 1519
# Next smallest at index 1 of value 5076
# Next smallest at index 0 of value 1677
# Next smallest at index 1 of value 4073
# Next smallest at index 0 of value 3732
# Next smallest at index 1 of value 2378
# Next smallest at index 1 of value 2017
# Next smallest at index 1 of value 2426
# Next smallest at index 0 of value 3251
# Next smallest at index 1 of value 4521
# Next smallest at index 1 of value 917
# Next smallest at index 0 of value 4290
# Next smallest at index 1 of value 1556
# Next smallest at index 0 of value 2217
# Next smallest at index 1 of value 2946
# Next smallest at index 1 of value 4590
# Next smallest at index 0 of value 1465
# Next smallest at index 1 of value 2125
# Next smallest at index 0 of value 3659
# Next smallest at index 0 of value 741
# Next smallest at index 1 of value 2139
# Next smallest at index 0 of value 1508
# Next smallest at index 0 of value 914
# Next smallest at index 0 of value 1014
# Next smallest at index 0 of value 638
# ...Processing Black
# ...Processing 18 and Over
# ...Processing Foster Care
# ...Processing 6 to 10
# ...Processing Native_American
# ...Processing 11 to 15
# ...Processing 2 departments
# ...Processing 4 departments
# ...Processing Other/Unknown
# ...Processing 1 to 2
# ...Processing CalWorks
# ...Processing 17 and Under
# ...Processing Unknown/Other Gender
# ...Processing WIC
# ...Processing 2 programs
# ...Processing Hispanic
# ...Processing 18 to 21
# ...Processing 1 department
# ...Processing CalFresh
# ...Processing Female
# ...Processing 16 to 17
# ...Processing Male
# ...Processing 65 and Over
# ...Processing 3 to 5
# ...Processing FPACT
# ...Processing 4 programs
# ...Processing 1 program
# ...Processing 3 programs
# ...Processing Medi-Cal
# ...Processing 5+ programs
# ...Processing 3 departments
# ...Processing Asian_PI
# ...Processing IHSS
# ...Processing White
# ...Processing 18-64
# ...Processing DDS
# ...Processing age 0
# ...Processing Person
# Next smallest at index 1 of value 13
# Next smallest at index 5 of value 43
# Next smallest at index 4 of value 77
# Next smallest at index 1 of value 17
# Next smallest at index 4 of value 13
# Next smallest at index 4 of value 12
# Next smallest at index 1 of value 0
# Next smallest at index 4 of value 100
# Next smallest at index 0 of value 227
# Next smallest at index 0 of value 1281
# Next smallest at index 0 of value 270
# Next smallest at index 0 of value 810
# Next smallest at index 0 of value 262
# Next smallest at index 0 of value 1301
# Next smallest at index 0 of value 983
# Next smallest at index 0 of value 1109
# Next smallest at index 0 of value 371
# Next smallest at index 0 of value 225
# Next smallest at index 0 of value 938
# Next smallest at index 0 of value 380
# Next smallest at index 0 of value 99
# Next smallest at index 0 of value 711
# Next smallest at index 0 of value 82
# Next smallest at index 0 of value 460
# Next smallest at index 0 of value 250
# Next smallest at index 0 of value 286
# Next smallest at index 1 of value 133
# Next smallest at index 0 of value 908
# Next smallest at index 0 of value 1772
# Next smallest at index 0 of value 771
# Next smallest at index 0 of value 30
# Next smallest at index 0 of value 272
# Next smallest at index 0 of value 1266
# Next smallest at index 0 of value 2270
# Next smallest at index 0 of value 134
# Next smallest at index 0 of value 247
# Next smallest at index 0 of value 2336
# Next smallest at index 0 of value 797
# Next smallest at index 0 of value 642
# Next smallest at index 3 of value 28
# Next smallest at index 2 of value 72
# Next smallest at index 0 of value 43
# Next smallest at index 2 of value 95
# Next smallest at index 2 of value 83
# Next smallest at index 2 of value 38
# Next smallest at index 2 of value 87
# Next smallest at index 2 of value 61
# Next smallest at index 2 of value 40
# Next smallest at index 2 of value 21
# Next smallest at index 2 of value 13
# Next smallest at index 2 of value 87
# Next smallest at index 2 of value 76
# Next smallest at index 2 of value 87
# Next smallest at index 2 of value 26
# Next smallest at index 3 of value 0
# Next smallest at index 2 of value 90
# Next smallest at index 2 of value 73
# Next smallest at index 0 of value 205
# Next smallest at index 0 of value 272
# Next smallest at index 0 of value 97
# Next smallest at index 0 of value 258
# Next smallest at index 0 of value 727
# Next smallest at index 0 of value 228
# Next smallest at index 0 of value 1241
# Next smallest at index 0 of value 1023
# Next smallest at index 0 of value 1112
# Next smallest at index 0 of value 371
# Next smallest at index 0 of value 210
# Next smallest at index 0 of value 963
# Next smallest at index 0 of value 317
# Next smallest at index 0 of value 656
# Next smallest at index 0 of value 1465
# Next smallest at index 0 of value 434
# Next smallest at index 0 of value 229
# Next smallest at index 0 of value 270
# Next smallest at index 0 of value 119
# Next smallest at index 0 of value 782
# Next smallest at index 0 of value 1608
# Next smallest at index 0 of value 681
# Next smallest at index 0 of value 356
# Next smallest at index 0 of value 453
# Next smallest at index 0 of value 213
# Next smallest at index 0 of value 713
# Next smallest at index 0 of value 632
# Next smallest at index 6 of value 15
# Next smallest at index 5 of value 11
# ...Processing Black
# ...Processing 18 and Over
# ...Processing Foster Care
# ...Processing 6 to 10
# The next smallest value for column 6 to 10 is at index 225 of value 11
# ...Processing Native_American
# ...Processing 11 to 15
# ...Processing 2 departments
# ...Processing 4 departments
# ...Processing Other/Unknown
# ...Processing 1 to 2
# ...Processing CalWorks
# ...Processing 17 and Under
# ...Processing Unknown/Other Gender
# ...Processing WIC
# ...Processing 2 programs
# The next smallest value for column 2 programs is at index 225 of value 14
# ...Processing Hispanic
# ...Processing 18 to 21
# ...Processing 1 department
# ...Processing CalFresh
# ...Processing Female
# ...Processing 16 to 17
# ...Processing Male
# ...Processing 65 and Over
# ...Processing 3 to 5
# ...Processing FPACT
# ...Processing 4 programs
# ...Processing 1 program
# The next smallest value for column 1 program is at index 225 of value 13
# ...Processing 3 programs
# The next smallest value for column 3 programs is at index 181 of value 13
# ...Processing Medi-Cal
# ...Processing 5+ programs
# ...Processing 3 departments
# ...Processing Asian_PI
# ...Processing IHSS
# ...Processing White
# The next smallest value for column White is at index 225 of value 37
# ...Processing 18-64
# ...Processing DDS
# ...Processing age 0
# ...Processing Person

# %%
r.to_excel("Masked_CWS_CMS_Dashboard_16.xlsx")
